# %%
# Modules de base
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm
import pandas as pd

# Module relatif à Gurobi
from gurobipy import *
import json

# %%
data_name = "toy_instance"

# %%
df = pd.read_csv(os.path.join("solution", data_name, "df_solution.csv"), index_col="index")

# %%
list_model = []
for index in df.index:
    model = read(df.loc[index, "model_path_mps"])
    model.read(df.loc[index, "model_path_sol"])
    model.params.outputflag = 0
    model.update()
    model.optimize()
    list_model.append(model)

df["model"] = list_model
# Out:
# Read MPS format model from file solution/toy_instance/model/0.mps
# Reading time = 0.01 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/1.mps
# Reading time = 0.01 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/2.mps
# Reading time = 0.01 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/3.mps
# Reading time = 0.00 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/4.mps
# Reading time = 0.00 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/7.mps
# Reading time = 0.00 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/8.mps
# Reading time = 0.00 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/9.mps
# Reading time = 0.00 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/13.mps
# Reading time = 0.00 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/14.mps
# Reading time = 0.00 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros
# Read MPS format model from file solution/toy_instance/model/25.mps
# Reading time = 0.00 seconds
# PL: 308 rows, 330 columns, 4563 nonzeros

# %%
df
# Out:
#            benef  max_duration  max_project_per_employee  \
# index
# 0       0.000000           0.0                       0.0
# 1     -20.000000           0.0                       1.0
# 2     -37.000000           0.0                       2.0
# 3     -49.000000           0.0                       3.0
# 4     -59.000000           0.0                       4.0
# 7     -30.000000           1.0                       1.0
# 8     -55.000000           1.0                       2.0
# 9     -65.000000           1.0                       3.0
# 13    -42.000000           2.0                       1.0
# 14    -65.000000           2.0                       2.0
# 25    -42.000006           2.0                       1.0
#
#                            model_path_sol                      model_path_mps  \
# index
# 0       solution/toy_instance/model/0.sol   solution/toy_instance/model/0.mps
# 1       solution/toy_instance/model/1.sol   solution/toy_instance/model/1.mps
# 2       solution/toy_instance/model/2.sol   solution/toy_instance/model/2.mps
# 3       solution/toy_instance/model/3.sol   solution/toy_instance/model/3.mps
# 4       solution/toy_instance/model/4.sol   solution/toy_instance/model/4.mps
# 7       solution/toy_instance/model/7.sol   solution/toy_instance/model/7.mps
# 8       solution/toy_instance/model/8.sol   solution/toy_instance/model/8.mps
# 9       solution/toy_instance/model/9.sol   solution/toy_instance/model/9.mps
# 13     solution/toy_instance/model/13.sol  solution/toy_instance/model/13.mps
# 14     solution/toy_instance/model/14.sol  solution/toy_instance/model/14.mps
# 25     solution/toy_instance/model/25.sol  solution/toy_instance/model/25.mps
#
#                                                    model
# index
# 0      <gurobi.Model MIP instance PL: 308 constrs, 33...
# 1      <gurobi.Model MIP instance PL: 308 constrs, 33...
# 2      <gurobi.Model MIP instance PL: 308 constrs, 33...
# 3      <gurobi.Model MIP instance PL: 308 constrs, 33...
# 4      <gurobi.Model MIP instance PL: 308 constrs, 33...
# 7      <gurobi.Model MIP instance PL: 308 constrs, 33...
# 8      <gurobi.Model MIP instance PL: 308 constrs, 33...
# 9      <gurobi.Model MIP instance PL: 308 constrs, 33...
# 13     <gurobi.Model MIP instance PL: 308 constrs, 33...
# 14     <gurobi.Model MIP instance PL: 308 constrs, 33...
# 25     <gurobi.Model MIP instance PL: 308 constrs, 33...

# %%
# Opening JSON file
#with open(df.loc[1, "model_path"]) as json_file:
 #   sol = json.load(json_file)

# %%
df.loc[0,"model"].ObjVal
# Out:
# 0.0
